# %% [markdown]
# # 単回帰分析(Simple Linear Regression)

# %%
# ライブラリのインポート
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %%
# データセットのインポート
dataset = pd.read_csv('Salary_Data.csv')
X = dataset.iloc[:, :-1]
y = dataset.iloc[:, -1]

# %%
# 訓練用データセットへの分割
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=1/3, random_state=0)

# %%
# 訓練用データセットを使った学習
from sklearn.linear_model import LinearRegression
regressor = LinearRegression()
regressor.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
# テストデータでの結果の予想
y_pred = regressor.predict(X_test)

# %%
# 結果の可視化
plt.scatter(X_train, y_train, color="red")
plt.plot(X_train, regressor.predict(X_train), color="blue")
plt.xlabel("Years of Exprience")
plt.ylabel("Salary")
plt.show()

# %%
# テストデータの結果の可視化
plt.plot(X_train, regressor.predict(X_train), color="blue")
plt.scatter(X_test, y_test, color="red")
plt.xlabel("Years of Exprience")
plt.ylabel("Salary")
plt.show()

# %%
# 就業年数12年の場合に対する給料の予測
print(regressor.predict([[12]]))
# Out:
# [138967.5015615]
# /Users/seinokaimu/machine-learning/venv/lib/python3.10/site-packages/sklearn/base.py:493: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(

# %%
# 切片と係数の取得
print(regressor.coef_)
print(regressor.intercept_)
# Out:
# [9345.94244312]
# 26816.19224403117
